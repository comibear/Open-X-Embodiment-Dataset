# %% [markdown]
# # DATASET

# %%
import numpy as np
import tensorflow_datasets as tfds
import tqdm
from PIL import Image
from IPython import display

import mujoco,sys
import numpy as np
import matplotlib.pyplot as plt

sys.path.append('../package/')
sys.path.append('../package/helper/')
sys.path.append('../package/mujoco_usage/')

from mujoco_parser import *
from transformation import *
from slider import *
from utility import *
from utils import *

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
print ("MuJoCo:[%s]"%(mujoco.__version__))
# Out:
# MuJoCo:[3.1.6]

# %%
dataset = DATASETS[43] # eth_agent_affordances
display_key = 'image'

ds, iterator = get_dataset(dataset, display_key=display_key)
# Out:
# 2025-02-05 00:49:04.760656: W external/local_tsl/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "FAILED_PRECONDITION: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Could not resolve host: metadata.google.internal".
# FeaturesDict({
#     'episode_metadata': FeaturesDict({
#         'file_path': Text(shape=(), dtype=string),
#         'input_point_cloud': Tensor(shape=(10000, 3), dtype=float16),
#     }),
#     'steps': Dataset({
#         'action': Tensor(shape=(6,), dtype=float32),
#         'discount': Scalar(shape=(), dtype=float32),
#         'is_first': bool,
#         'is_last': bool,
#         'is_terminal': bool,
#         'language_embedding': Tensor(shape=(512,), dtype=float32),
#         'language_instruction': Text(shape=(), dtype=string),
#         'observation': FeaturesDict({
#             'image': Image(shape=(64, 64, 3), dtype=uint8),
#             'input_point_cloud': Tensor(shape=(10000, 3), dtype=float16),
#             'state': Tensor(shape=(8,), dtype=float32),
#         }),
#         'reward': Scalar(shape=(), dtype=float32),
#     }),
# })

# %%
episode = next(iterator)
images = get_image_from_episode(episode, display_key=display_key)

import os
from PIL import Image
import numpy as np
os.environ["IMAGEIO_FFMPEG_EXE"] = "/opt/homebrew/bin/ffmpeg"

from moviepy import *

frames = [np.array(img.convert('RGB')) for img in images]
clip = ImageSequenceClip(frames, fps=3)
clip.write_videofile("output.mp4", codec='libx264', audio=False)
# Out:
# 2025-02-05 00:49:09.226896: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:376] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# 2025-02-05 00:49:25.725613: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:6: Filling up shuffle buffer (this may take a while): 1 of 30
# 2025-02-05 00:49:40.552419: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:6: Filling up shuffle buffer (this may take a while): 10 of 30
# 2025-02-05 00:49:57.850590: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:6: Filling up shuffle buffer (this may take a while): 13 of 30
# 2025-02-05 00:50:03.856604: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 2025-02-05 00:50:04.000963: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# MoviePy - Building video output.mp4.
# MoviePy - Writing video output.mp4
# MoviePy - Done !
# MoviePy - video ready output.mp4

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def arr2image(array):
    """
    Displays a NumPy array (h, w, c) as an image.
    """
    # Check the array shape and type
    if len(array.shape) != 3 or array.shape[2] not in [3, 4]:
        raise ValueError("Input array must have shape (h, w, c) with c=3 (RGB) or c=4 (RGBA).")
    
    # Display the image using matplotlib
    plt.imshow(array)
    plt.axis('off')  # Turn off axis
    plt.show()

# %% [markdown]
# # EPISODE

# %%
iter_steps = iter(episode['steps'])
states = [state['observation']['state'] for state in iter_steps] # Joint states

iter_steps = iter(episode['steps'])
actions = [state['action'] for state in iter_steps]

iter_steps = iter(episode['steps'])
point_cloud = np.array([state['observation']['input_point_cloud'] for state in iter_steps])
# Out:
# 2025-02-05 00:50:04.666135: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-05 00:50:04.926326: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
import numpy as np
import matplotlib.pyplot as plt

i = 1000

# 3D 시각화
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# X, Y, Z 좌표 분리
x = point_cloud[i][:, 0]
y = point_cloud[i][:, 1]
z = point_cloud[i][:, 2]

# 점 그리기
ax.scatter(x, y, z, s=3, alpha=0.5)  # 작은 점으로 표현
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.set_title("3D Point Cloud Visualization")

plt.show()

# %% [markdown]
# # ENV

# %%
xml_path = '../mujoco_menagerie/franka_emika_panda/scene.xml'
env = MuJoCoParserClass(name='Tabletop',rel_xml_path=xml_path,verbose=False)

# %% [markdown]
# # CONTROL

# %%
# Visualize environment with initial pose from trajectory
env.init_viewer()

joint_names = ['joint1','joint2','joint3','joint4','joint5','joint6','joint7']
q0 = np.deg2rad([0.0, 0.0, 0.0, -90.0, 0.0, 90.0, 0.0])

env.reset()
env.forward(q=q0, joint_names=joint_names)

while env.is_viewer_alive():
  if env.loop_every(tick_every=10):
    env.plot_T(
        T=env.get_T_body(body_name='link0'),
        axis_len=0.5,print_xyz=False)
    
    env.plot_body_T(body_name='tcp_link',axis_len=0.1,axis_width=0.005)
    env.plot_contact_info(
        r_arrow=0.005,h_arrow=0.1,rgba_contact=(1,0,0,0.5),plot_sphere=False)
    
    env.render()

env.close_viewer()

# %%
sliders = MultiSliderClass( # Slider for EE control
    n_slider      = 7,
    title         = 'Sliders for [%s] Control'%(env.name),
    window_width  = 450,
    window_height = 300,
    x_offset      = 0,
    y_offset      = 100,
    slider_width  = 300,
    label_texts   = ['X','Y','Z','Roll-deg','Pitch-deg','Yaw-deg','Gripper'],
    slider_mins   = [-1,-1,0,-180,-180,-180,0],
    slider_maxs   = [+1,+1,1.2,+180,+180,+180,255],
    slider_vals   = [0,0,0,0,0,0,0],
    resolutions   = [0.02,0.02,0.02,3.6,3.6,3.6,0.04], # range/50
    verbose       = False,
)

joint_names = env.joint_names

# Don't Know Why.....
# q0 = np.array([0, -1, 0, 1, 6, 1.7, 0])

q0 = np.zeros(len(joint_names), dtype=float)
#q0 = q_traj[60]

env.init_viewer(
    title       = 'Tabletop',
    transparent = False,
    azimuth     = 133,
    distance    = 3.5,
    elevation   = -42.4,
    lookat      = (-0.06,0.07,0.31),
)

env.reset() # reset
env.forward(q=q0,joint_names=joint_names) # initial position

p0 = env.get_p_body(body_name='tcp_link')
R0 = env.get_R_body(body_name='tcp_link')

# Loop
q_ik_init = q0.copy()
while env.is_viewer_alive():
    
    # Update
    sliders.update() # update slider
    xyzrpyg = sliders.get_slider_values()
    qpos,ik_err_stack,ik_info = solve_ik(
        env                = env,
        joint_names_for_ik = joint_names,
        body_name_trgt     = 'tcp_link',
        q_init             = q_ik_init,
        p_trgt             = xyzrpyg[:3]+p0,
        R_trgt             = rpy_deg2r(xyzrpyg[3:6])@R0,
        max_ik_tick        = 500,
        ik_stepsize        = 1.0,
        ik_eps             = 1e-2,
        ik_th              = np.radians(5.0),
        render             = False,
        verbose_warning    = False,
    )
    ik_err = np.abs(ik_err_stack).max() # IK error
    if ik_err < 1e-2: q_ik_init = qpos.copy()
    else: q_ik_init = q0.copy()
    
    env.step( # dynamic update
        ctrl        = qpos, #np.append(np.append(qpos,xyzrpyg[6]),xyzrpyg[6]),s
        joint_names = joint_names
    )
    
    # Render 
    if env.loop_every(tick_every=10):
        env.plot_T(
            T=env.get_T_body(body_name='base_link'),
            axis_len=0.5,print_xyz=False)
        env.plot_text(
            p=env.get_p_body(body_name='base_link')+np.array([0,0,0.5]),
            label = 'time:[%.2f]sec ik_err:[%.3f]'%(env.get_sim_time(),ik_err))
        env.plot_body_T(body_name='tcp_link',axis_len=0.1,axis_width=0.005)
        env.plot_contact_info(
            r_arrow=0.005,h_arrow=0.1,rgba_contact=(1,0,0,0.5),plot_sphere=False)
        plot_ik_info(env=env,ik_info=ik_info)
        
        env.render()

# Close
env.close_viewer()
sliders.close()
print ("Done.")
# Out:
# Done.

# %%
sliders = MultiSliderClass( # Slider for joint control
    n_slider      = 8,
    title         = 'Sliders for [%s] Control'%(env.name),
    window_width  = 450,
    window_height = 300,
    x_offset      = 0,
    y_offset      = 100,
    slider_width  = 300,
    label_texts   = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Joint 7', 'Gripper'],
    slider_mins   = np.degrees(env.joint_ranges[:,0]).tolist() + [0], # Convert joint ranges from radians to degrees
    slider_maxs   = np.degrees(env.joint_ranges[:,1]).tolist() + [255],
    slider_vals   = [0, 0, 0, 0, 0, 0, 0, 0],
    resolutions   = [(max-min)/50 for min,max in zip(np.degrees(env.joint_ranges[:,0]).tolist() + [0], 
                                                    np.degrees(env.joint_ranges[:,1]).tolist() + [255])],
    verbose       = False,
)

joint_names = env.joint_names
q0 = np.array([0.0,             # Joint 1 
               1.1426,          # Joint 2
               -0.0002,         # Joint 3 
               1.1451,          # Joint 4
               -0.0001,         # Joint 5
               0.9371,          # Joint 6
               0.0000])         # Joint 7

#   q0 = np.zeros(len(joint_names), dtype=float)

env.init_viewer(
    title       = 'Tabletop',
    transparent = False,
    azimuth     = 133,
    distance    = 3.5,
    elevation   = -42.4,
    lookat      = (-0.06,0.07,0.31),
)
env.reset() # reset
env.forward(q=q0,joint_names=joint_names) # initial position

# Loop
while env.is_viewer_alive():
    
    # Update
    sliders.update() # update slider
    joint_values = sliders.get_slider_values()
    
    # Convert degrees to radians for joint angles
    qpos = np.radians(joint_values[:7])
    
    env.forward( # static update
        q           = qpos, # Last value is gripper
        joint_names = joint_names
    )
    
    # Render 
    if env.loop_every(tick_every=10):
        env.plot_T(
            T=env.get_T_body(body_name='base_link'),
            axis_len=0.5,print_xyz=False)
        env.plot_text(
            p=env.get_p_body(body_name='base_link')+np.array([0,0,0.5]),
            label = 'time:[%.2f]sec'%(env.get_sim_time()))
        env.plot_body_T(body_name='tcp_link',axis_len=0.1,axis_width=0.005)
        env.plot_contact_info(
            r_arrow=0.005,h_arrow=0.1,rgba_contact=(1,0,0,0.5),plot_sphere=False)
        
        env.render()

# Close
env.close_viewer()
sliders.close()
print ("Done.")
# Out:
# Done.

# %% [markdown]
# # Trajectory

# %% [markdown]
# ### 1) genration

# %%
joint_names = ['joint1','joint2','joint3','joint4','joint5','joint6','joint7']

#q0 = np.zeros_like(joint_names, dtype=float)
q0 = np.deg2rad([0.0, 0.0, 0.0, -90.0, 0.0, 90.0, 0.0])

q_traj = []

q_ik_init = q0.copy()
for ik_target in states:

    qpos,ik_err_stack,ik_info = solve_ik(
        env                = env,
        joint_names_for_ik = joint_names,
        body_name_trgt     = 'tcp_link',
        q_init             = q_ik_init,
        p_trgt             = ik_target[:3],
        R_trgt             = rpy2r(ik_target[3:6]),
        max_ik_tick        = 500,
        ik_stepsize        = 1.0,
        ik_eps             = 1e-2,
        ik_th              = np.radians(5.0),
        render             = False,
        verbose_warning    = False,
    )

    ik_err = np.abs(ik_err_stack).max() # IK error
    if ik_err < 1e-2: q_ik_init = qpos.copy()
    else: q_ik_init = q0.copy()
    
    # print(ik_err, ik_target[:3], rot_target)
    q_traj.append(qpos)

# %% [markdown]
# ### 2) Comparing

# %%
# G -> B -> R

idx = 10
assert idx < len(frames)

sliders = MultiSliderClass( # Slider for EE control
    n_slider      = 7,
    title         = 'Sliders for [%s] Control'%(env.name),
    window_width  = 450,
    window_height = 300,
    x_offset      = 0,
    y_offset      = 100,
    slider_width  = 300,
    label_texts   = ['X','Y','Z','Roll-deg','Pitch-deg','Yaw-deg','Gripper'],
    slider_mins   = [-1,-1,0,-180,-180,-180,0],
    slider_maxs   = [+1,+1,1.2,+180,+180,+180,2],
    slider_vals   = [0,0,0,0,0,0,0],
    resolutions   = [0.02,0.02,0.02,3.6,3.6,3.6,0.04], # range/50
    verbose       = False,
)

joint_names = ['joint1','joint2','joint3','joint4','joint5','joint6','joint7']
env.reset(step=True)

q0 = q_traj[idx]
env.forward(q=q0,joint_names=joint_names) # initial position

p0 = env.get_p_body(body_name='tcp_link')
R0 = env.get_R_body(body_name='tcp_link')

env.init_viewer(
    title       = 'Tabletop',
    transparent = False,
    azimuth     = 133,
    distance    = 3.5,
    elevation   = -42.4,
    lookat      = (-0.06,0.07,0.31),
)

arr2image(frames[idx])

# Loop
q_ik_init = q0.copy()
while env.is_viewer_alive():
    
    # Update
    sliders.update() # update slider
    xyzrpyg = sliders.get_slider_values()
    qpos,ik_err_stack,ik_info = solve_ik(
        env                = env,
        joint_names_for_ik = joint_names,
        body_name_trgt     = 'tcp_link',
        q_init             = q_ik_init,
        p_trgt             = xyzrpyg[:3]+p0,
        R_trgt             = rpy_deg2r(xyzrpyg[3:6])@R0,
        max_ik_tick        = 500,
        ik_stepsize        = 1.0,
        ik_eps             = 1e-2,
        ik_th              = np.radians(5.0),
        render             = False,
        verbose_warning    = False,
    )
    
    ik_err = np.abs(ik_err_stack).max() # IK error
    if ik_err < 1e-2: q_ik_init = qpos.copy()
    else: q_ik_init = q0.copy()
    
    env.step( # dynamic update
        ctrl        = qpos,
        joint_names = joint_names
    )
    
    # Render 
    if env.loop_every(tick_every=10):
        env.plot_T(
            T=env.get_T_body(body_name='link0'),
            axis_len=0.5,print_xyz=False)
        env.plot_text(
            p=env.get_p_body(body_name='link0')+np.array([0,0,0.5]),
            label = 'time:[%.2f]sec ik_err:[%.3f]'%(env.get_sim_time(),ik_err))
        env.plot_body_T(body_name='tcp_link',axis_len=0.1,axis_width=0.005)
        env.plot_contact_info(
            r_arrow=0.005,h_arrow=0.1,rgba_contact=(1,0,0,0.5),plot_sphere=False)
        plot_ik_info(env=env,ik_info=ik_info)
        
        env.render()

# Close
env.close_viewer()
sliders.close()
print("Done.")
# Out:
# 2025-01-27 17:48:25.180 python[35161:2225993] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-01-27 17:48:25.180 python[35161:2225993] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 2025-01-27 17:49:45.412 python[35161:2225993] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit
# Done.

# %% [markdown]
# # Trajectory Reappearance

# %%
joint_names = ['joint1','joint2','joint3','joint4','joint5','joint6','joint7']
q0 = np.zeros_like(joint_names, dtype=float)

env.init_viewer()

env.reset() # reset
env.forward(q=q0,joint_names=joint_names) # iEitial position
    
# Loop
q_ik_init = q0.copy()
qpos = q_traj[0]
idx = 0

while env.is_viewer_alive():
    env.forward(q=qpos,joint_names=joint_names)

    # Render 
    if env.loop_every(HZ=1):
        if idx < len(q_traj)-1:
            idx += 1
        else: idx = 0

        qpos = q_traj[idx]

        env.plot_T(
            T=env.get_T_body(body_name='link0'),
            axis_len=0.5,print_xyz=False)
        env.plot_text(
            p=env.get_p_body(body_name='link0')+np.array([0,0,0.5]),
            label = 'tick:[%d]time:[%.2f]'%(idx, env.get_sim_time()))
        env.plot_body_T(body_name='tcp_link',axis_len=0.1,axis_width=0.005)
        
        env.render()

# Close
env.close_viewer()
print ("Done.")
# Out:
# Done.

# %%
joint_names = env.joint_names
q0 = np.zeros_like(joint_names, dtype=float)

env.init_viewer()

env.reset() # reset
env.forward(q=q0,joint_names=joint_names) # initial position
    
# Loop
q_ik_init = q0.copy()
qpos = states[0][:7]
idx = 0

while env.is_viewer_alive():
    env.forward(q=qpos,joint_names=joint_names)

    # Render 
    if env.loop_every(HZ=1):

        if idx < len(states)-1:
            idx += 1
        else: idx = 0

        qpos = states[idx][:7]  # Use first 7 joints from joint_states

        env.plot_T(
            T=env.get_T_body(body_name='base'),
            axis_len=0.5,print_xyz=False)
        env.plot_text(
            p=env.get_p_body(body_name='base')+np.array([0,0,0.5]),
            label = 'tick:[%d]time:[%.2f]'%(idx, env.get_sim_time()))
        env.plot_body_T(body_name='tcp_link',axis_len=0.1,axis_width=0.005)
        
        env.render()

# Close
env.close_viewer()
print ("Done.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 15
#      12 idx = 0
#      14 while env.is_viewer_alive():
# ---> 15     env.forward(q=qpos,joint_names=joint_names)
#      17     # Render
#      18     if env.loop_every(HZ=1):
#
# File ~/Desktop/Robotics/RILAB/StateTransform/notebook/../package/mujoco_usage/mujoco_parser.py:443, in MuJoCoParserClass.forward(self, q, joint_idxs, joint_names, increase_tick)
#     441         joint_idxs = self.get_idxs_fwd(joint_names=joint_names)
#     442     if joint_idxs is not None:
# --> 443         self.data.qpos[joint_idxs] = q
#     444     else: self.data.qpos = q
#     445 mujoco.mj_forward(self.model,self.data)
#
# ValueError: shape mismatch: value array of shape (7,) could not be broadcast to indexing result of shape (9,)

# %% [markdown]
# # Reverse Engineering

# %%
# current link gripper -> tcp_link rpy 0,0,0
# target link gripper -> target rpy

target = states[idx][3:6]
target = rpy2r(target)

base = env.get_R_body(body_name='link7')
current = env.get_R_body(body_name='tcp_link')

R = current.T@base
rpy = r2rpy(R)
# print(rpy)

R = base.T@target
rpy = r2rpy(R)
# print(rpy)
print(rpy2quat(rpy))
# Out:
# [ 0.00235569 -0.32037747 -0.94721001  0.01207949]

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# 예시 point_cloud.shape = (num_frames, num_points, 3)
num_frames = len(point_cloud)

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

def update(frame):
    ax.clear()
    
    x = point_cloud[frame][:, 0]
    y = point_cloud[frame][:, 1]
    z = point_cloud[frame][:, 2]

    ax.scatter(x, y, z, s=3, alpha=0.5)
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")
    ax.set_title(f"3D Point Cloud Visualization - Frame {frame}")

# frames = range(num_frames)는 0부터 num_frames-1까지 순회
ani = animation.FuncAnimation(fig, update, frames=range(num_frames), interval=10)
ani.save("output.mp4", writer="ffmpeg", fps=30)

# plt.show()
